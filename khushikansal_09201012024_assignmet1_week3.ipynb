# %%
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_csv("agriculture_yield_dataset.csv")

# %%
data.columns
# Out:
# Index(['rainfall_mm', 'temperature_c', 'fertilizer_kg', 'irrigation_hours',
#        'soil_ph', 'crop_type', 'soil_type', 'yield_ton_per_hectare'],
#       dtype='object')

# %%
data.head(10)
# Out:
#    rainfall_mm  temperature_c  fertilizer_kg  irrigation_hours  soil_ph  \
# 0        588.6           18.6          242.4               6.5      6.5
# 1        772.8           34.6          247.2              10.0      6.5
# 2        970.9           36.3          168.4               7.3      6.4
# 3        611.7           19.0          121.7               3.7      6.0
# 4        696.1           29.6          184.6               5.1      6.1
# 5        831.9           28.0          190.3               2.1      6.1
# 6       1023.8           32.0          108.5               6.9      6.2
# 7       1142.4           18.4          241.9               4.1      7.3
# 8        810.4           36.4          164.8               9.9      6.5
# 9       1085.5           29.4           89.3               8.3      5.8
#
#   crop_type soil_type  yield_ton_per_hectare
# 0     Maize     Loamy                   5.92
# 1     Maize     Sandy                   6.24
# ...

# %%
data.dtypes
# Out:
# rainfall_mm              float64
# temperature_c            float64
# fertilizer_kg            float64
# irrigation_hours         float64
# soil_ph                  float64
# crop_type                 object
# soil_type                 object
# yield_ton_per_hectare    float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# rainfall_mm              0
# temperature_c            0
# fertilizer_kg            0
# irrigation_hours         0
# soil_ph                  0
# crop_type                0
# soil_type                0
# yield_ton_per_hectare    0
# dtype: int64

# %%
data.describe()
# Out:
#        rainfall_mm  temperature_c  fertilizer_kg  irrigation_hours  \
# count  1500.000000    1500.000000    1500.000000       1500.000000
# mean    754.054667      27.749467     148.744067          5.403267
# std     255.097216       5.758101      56.990279          2.584329
# min     300.200000      18.000000      50.300000          1.000000
# 25%     536.175000      22.600000      98.600000          3.200000
# 50%     761.200000      27.700000     146.850000          5.400000
# 75%     964.375000      32.600000     196.575000          7.600000
# max    1200.000000      38.000000     249.900000         10.000000
#
#            soil_ph  yield_ton_per_hectare
# count  1500.000000            1500.000000
# mean      6.759133               5.028793
# std       0.719742               0.968282
# min       5.500000               2.090000
# 25%       6.100000               4.337500
# 50%       6.800000               5.010000
# 75%       7.400000               5.740000
# ...

# %%
dataf=data.mean(numeric_only=True)
print(dataf)
print(dataf.max())
# Out:
# rainfall_mm              754.054667
# temperature_c             27.749467
# fertilizer_kg            148.744067
# irrigation_hours           5.403267
# soil_ph                    6.759133
# yield_ton_per_hectare      5.028793
# dtype: float64
# 754.0546666666667

# %%
dataf2=data.std(numeric_only=True)
print(dataf2.max())
# Out:
# 255.0972161445094

# %%
#Q4
plt.hist(data['rainfall_mm'])
plt.show()

# %%
plt.hist(data['temperature_c'])
plt.show()

# %%
plt.hist(data['fertilizer_kg'])
plt.show()

# %%
plt.hist(data['yield_ton_per_hectare'])
plt.show()

# %%
crop_counts = data['crop_type'].value_counts()

print(crop_counts)
# Out:
# crop_type
# Cotton     311
# Soybean    306
# Wheat      303
# Rice       293
# Maize      287
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='crop_type', data=data)

plt.title("Crop Type Distribution")
plt.xlabel("Crop Type")
plt.ylabel("Count")
plt.xticks(rotation=45)

plt.show()

# %%
print(data['crop_type'].value_counts().idxmax())
# Out:
# Cotton

# %%
soil_counts = data['soil_type'].value_counts()

print(soil_counts)
# Out:
# soil_type
# Clay     534
# Sandy    492
# Loamy    474
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='soil_type', data=data)

plt.title("Soil Type Distribution")
plt.xlabel("Soil Type")
plt.ylabel("Count")
plt.xticks(rotation=45)

plt.show()

# %%
most_common_soil = data['soil_type'].value_counts().idxmax()

print("Most common soil type:", most_common_soil)
# Out:
# Most common soil type: Clay

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(data['yield_ton_per_hectare'], bins=20)
plt.title('Yield Distribution')
plt.xlabel('Yield (ton/hectare)')
plt.ylabel('Frequency')
plt.show()

# %%
print(data['yield_ton_per_hectare'].describe())
# Out:
# count    1500.000000
# mean        5.028793
# std         0.968282
# min         2.090000
# 25%         4.337500
# 50%         5.010000
# 75%         5.740000
# max         7.860000
# Name: yield_ton_per_hectare, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.scatter(data['rainfall_mm'], data['yield_ton_per_hectare'])
plt.xlabel('Rainfall (mm)')
plt.ylabel('Yield (ton/hectare)')
plt.title('Rainfall vs Yield')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(data['fertilizer_kg'], data['yield_ton_per_hectare'])
plt.xlabel('Fertilizer (kg)')
plt.ylabel('Yield (ton/hectare)')
plt.title('Fertilizer vs Yield')
plt.show()

# %%
print(data[['rainfall_mm','yield_ton_per_hectare']].corr())
print(data[['fertilizer_kg','yield_ton_per_hectare']].corr())
# Out:
#                        rainfall_mm  yield_ton_per_hectare
# rainfall_mm               1.000000               0.553704
# yield_ton_per_hectare     0.553704               1.000000
#                        fertilizer_kg  yield_ton_per_hectare
# fertilizer_kg               1.000000               0.278043
# yield_ton_per_hectare       0.278043               1.000000

# %%
corr_matrix = data.corr(numeric_only=True)

print(corr_matrix)
# Out:
#                        rainfall_mm  temperature_c  fertilizer_kg  \
# rainfall_mm               1.000000       0.026721       0.002558
# temperature_c             0.026721       1.000000       0.037468
# fertilizer_kg             0.002558       0.037468       1.000000
# irrigation_hours          0.010877       0.007114      -0.010497
# soil_ph                   0.006916       0.001513       0.010001
# yield_ton_per_hectare     0.553704      -0.022559       0.278043
#
#                        irrigation_hours   soil_ph  yield_ton_per_hectare
# rainfall_mm                    0.010877  0.006916               0.553704
# temperature_c                  0.007114  0.001513              -0.022559
# fertilizer_kg                 -0.010497  0.010001               0.278043
# irrigation_hours               1.000000  0.009307               0.542664
# soil_ph                        0.009307  1.000000               0.024412
# yield_ton_per_hectare          0.542664  0.024412               1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
yield_corr = corr_matrix['yield_ton_per_hectare'].sort_values(ascending=False)

print(yield_corr)
# Out:
# yield_ton_per_hectare    1.000000
# rainfall_mm              0.553704
# irrigation_hours         0.542664
# fertilizer_kg            0.278043
# soil_ph                  0.024412
# temperature_c           -0.022559
# Name: yield_ton_per_hectare, dtype: float64

# %%
crop_yield = data.groupby('crop_type')['yield_ton_per_hectare'].mean()

print(crop_yield)
# Out:
# crop_type
# Cotton     4.607299
# Maize      4.897143
# Rice       5.494744
# Soybean    5.173431
# Wheat      4.989472
# Name: yield_ton_per_hectare, dtype: float64

# %%
soil_yield = data.groupby('soil_type')['yield_ton_per_hectare'].mean()

print(soil_yield)
# Out:
# soil_type
# Clay     5.134326
# Loamy    5.366519
# Sandy    4.588882
# Name: yield_ton_per_hectare, dtype: float64

# %%
categorical_cols = data.select_dtypes(include=['object']).columns

print(categorical_cols)
# Out:
# Index(['crop_type', 'soil_type'], dtype='object')

# %%
data_encoded = pd.get_dummies(
    data,
    columns=categorical_cols,
    drop_first=True
)

# %%
data_encoded.head()
# Out:
#    rainfall_mm  temperature_c  fertilizer_kg  irrigation_hours  soil_ph  \
# 0        588.6           18.6          242.4               6.5      6.5
# 1        772.8           34.6          247.2              10.0      6.5
# 2        970.9           36.3          168.4               7.3      6.4
# 3        611.7           19.0          121.7               3.7      6.0
# 4        696.1           29.6          184.6               5.1      6.1
#
#    yield_ton_per_hectare  crop_type_Maize  crop_type_Rice  crop_type_Soybean  \
# 0                   5.92             True           False              False
# 1                   6.24             True           False              False
# 2                   4.77            False           False              False
# 3                   4.04             True           False              False
# 4                   5.17            False           False              False
#
#    crop_type_Wheat  soil_type_Loamy  soil_type_Sandy
# ...

# %%
y = data_encoded['yield_ton_per_hectare']

# %%
X = data_encoded.drop('yield_ton_per_hectare', axis=1)

# %%
print("Target Variable:")
print(y.name)

print("\nFeatures:")
print(X.columns)
# Out:
# Target Variable:
# yield_ton_per_hectare
#
# Features:
# Index(['rainfall_mm', 'temperature_c', 'fertilizer_kg', 'irrigation_hours',
#        'soil_ph', 'crop_type_Maize', 'crop_type_Rice', 'crop_type_Soybean',
#        'crop_type_Wheat', 'soil_type_Loamy', 'soil_type_Sandy'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print("Intercept:")
print(model.intercept_)

print("\nCoefficients:")
print(model.coef_)
# Out:
# Intercept:
# 1.587132027736121
#
# Coefficients:
# [ 0.00203545 -0.00917496  0.00497799  0.19832728  0.00490119  0.23893088
#   0.86399284  0.48171939  0.34847403  0.30297421 -0.49093272]

# %%
coef_df = pd.DataFrame({
    'Feature': X.columns,
    'Coefficient': model.coef_
})

highest_feature = coef_df.loc[
    coef_df['Coefficient'].idxmax()
]

print(highest_feature)
# Out:
# Feature        crop_type_Rice
# Coefficient          0.863993
# Name: 6, dtype: object
